# %%
from PIL import Image
import os

image_dir = 'C:/workspace_project/jupyter_lab/Test1/images/'

# 디렉토리 내의 모든 이미지 파일에 대해
for filename in os.listdir(image_dir):
    # 파일 확장자가 .jpg인 경우에만 처리
    if filename.endswith('.jpg'):
        # 이미지 파일 열기
        image_path = os.path.join(image_dir, filename)
        image = Image.open(image_path)

        # 원본 이미지 크기 확인
        original_size = image.size
        print(f'Original size: {original_size}')

        # 비율 설정 (예: 원본 크기의 10%)
        ratio = 0.5

        # 새로운 크기 계산
        new_size = (int(original_size[0]*ratio), int(original_size[1]*ratio))

        # 이미지 크기 조정
        resized_image = image.resize(new_size)

        # 조정된 이미지 크기 확인
        print(f'Resized size: {resized_image.size}')

        # 조정된 이미지 저장
        resized_image_path = os.path.join(image_dir, 'resized_' + filename)
        resized_image.save(resized_image_path)
print("done!")
# Out:
# Original size: (4000, 3000)
# Resized size: (2000, 1500)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (534, 1513)
# Resized size: (267, 756)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# Original size: (1275, 1650)
# Resized size: (637, 825)
# done!
